# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\Admin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from datetime import datetime
import pandas as pd
from datetime import datetime

# Load your CSV
df = pd.read_csv("C:/Users/Admin/OneDrive/Desktop/custom_data.csv")

# Add the 'last_updated' column with the current date and time
df['last_updated'] = datetime.now().strftime('%Y-%m-%dT%H:%M:%SZ')

# Save back to CSV
df.to_csv("C:/Users/Admin/OneDrive/Desktop/custom_data.csv", index=False)
# Display the first few rows of the DataFrame
df.head(60)
# Out:
#    student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0       S1000   23  Female                  0.0                 1.2
# 1       S1001   20  Female                  6.9                 2.8
# 2       S1002   21    Male                  1.4                 3.1
# 3       S1003   23  Female                  1.0                 3.9
# 4       S1004   19  Female                  5.0                 4.4
# 5       S1005   24    Male                  7.2                 1.3
# 6       S1006   21  Female                  5.6                 1.5
# 7       S1007   21  Female                  4.3                 1.0
# 8       S1008   23  Female                  4.4                 2.2
# 9       S1009   18  Female                  4.8                 3.1
# 10      S1010   19  Female                  4.6                 3.7
# 11      S1011   23    Male                  3.9                 2.4
# 12      S1012   19  Female                  3.7                 2.1
# ...
